# %%
class football_club():
    name_club = ''
    city_club = ''
    points_club = 0

class Championship(football_club):
    country_champ = 'England'
    name_сhamp = 'Premier League'
    list_team_champ = []

    def add_team(self, new_team):
        self.list_team_champ.append(new_team)

    def print_team(self):
            for curent_teams in self.list_team_champ:
                print('Назва клубу: ', curent_teams.name_club,', Місто клубу: ', curent_teams.city_club, ', Бали клубу:',curent_teams.points_club)

    def team_min_points(self):
        min=1000
        for min_points in self.list_team_champ:
            if min_points.points_club < min:
                min=min_points.points_club

        for min_points in self.list_team_champ:
            if min_points.points_club == min:
                print('Клуб', min_points.name_club,'має найменшу кількість балів', min_points.points_club)


championship = Championship()

Liverpool = football_club()
Liverpool.name_club = 'Liverpool'
Liverpool.city_club = 'Liverpool'
Liverpool.points_club = 34

Chelsya = football_club()
Chelsya.name_club = 'Chelsya'
Chelsya.city_club = 'London'
Chelsya.points_club = 45

Juventus = football_club()
Juventus.name_club = 'Juventus'
Juventus.city_club = 'Italy'
Juventus.points_club = 67

championship.add_team(Chelsya)
championship.add_team(Liverpool)
championship.add_team(Juventus)

championship.print_team()
championship.team_min_points()
# Out:
# Назва клубу:  Chelsya , Місто клубу:  London , Бали клубу: 45
# Назва клубу:  Liverpool , Місто клубу:  Liverpool , Бали клубу: 34
# Назва клубу:  Juventus , Місто клубу:  Italy , Бали клубу: 67
# Клуб Liverpool має найменшу кількість балів 34

# %%
class football_club():
    name_club = ''
    city_club = ''
    points_club = 0

class Championship(football_club):
    country_champ = 'England'
    name_сhamp = 'Premier League'
    list_team_champ = []

    def print_team(self):
            for curent_teams in self.list_team_champ:
                print('Назва клубу: ', curent_teams.name_club,', Місто клубу: ', curent_teams.city_club, ', Бали клубу:',curent_teams.points_club)

    def team_min_points(self):
        min_points = self.list_team_champ[0]
        for current_team in self.list_team_champ:
            if current_team.points_club < min_points.points_club:
                min_points = current_team
        print('Клуб', min_points.name_club,',з міста',min_points.city_club, ', має найменшу кількість балів', min_points.points_club)
        print('У Чемпіонаті',self.name_сhamp,'у місті',self.country_champ )    
        print('')
    
    def team_max_points(self):
        max_points = self.list_team_champ[0]
        for current_team in self.list_team_champ:
            if current_team.points_club > max_points.points_club:
                max_points = current_team
        print('Клуб', max_points.name_club,',з міста',max_points.city_club, ', має найбільшу кількість балів', max_points.points_club)
        print('У Чемпіонаті',self.name_сhamp,'у місті',self.country_champ )
    
    def add_student(self, new_club):
        self.list_team_champ.append(new_club)




championship = Championship()

Liverpool = football_club()
Liverpool.name_club = 'Liverpool'
Liverpool.city_club = 'Liverpool'
Liverpool.points_club = 34

Chelsya = football_club()
Chelsya.name_club = 'Chelsya'
Chelsya.city_club = 'London'
Chelsya.points_club = 45

Juventus = football_club()
Juventus.name_club = 'Juventus'
Juventus.city_club = 'Italy'
Juventus.points_club = 67

Real = football_club()
Real.name_club = 'Real Madrid'
Real.city_club = 'Madrid'
Real.points_club = 56

Bavaria = football_club()
Bavaria.name_club = 'Bavaria'
Bavaria.city_club = 'Munxin'
Bavaria.points_club = 33



championship.add_student(Chelsya)
championship.add_student(Liverpool)
championship.add_student(Juventus)
championship.add_student(Real)
championship.add_student(Bavaria)

championship.print_team()
print('')
championship.team_min_points()
championship.team_max_points()
# Out:
# Назва клубу:  Chelsya , Місто клубу:  London , Бали клубу: 45
# Назва клубу:  Liverpool , Місто клубу:  Liverpool , Бали клубу: 34
# Назва клубу:  Juventus , Місто клубу:  Italy , Бали клубу: 67
# Назва клубу:  Real Madrid , Місто клубу:  Madrid , Бали клубу: 56
# Назва клубу:  Bavaria , Місто клубу:  Munxin , Бали клубу: 33
#
# Клуб Bavaria ,з міста Munxin , має найменшу кількість балів 33
# У Чемпіонаті Premier League у місті England
#
# Клуб Juventus ,з міста Italy , має найбільшу кількість балів 67
# У Чемпіонаті Premier League у місті England
